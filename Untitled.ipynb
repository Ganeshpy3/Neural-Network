# %%
import pandas as pd
import numpy as np

# %%
X=pd.read_csv("train_X.csv").values.T
Y=pd.read_csv("train_label.csv").values.T

# %%
import matplotlib.pyplot  as plt

# %%
plt.imshow(X[:,450].reshape(28, 28), cmap = 'gray')
plt.show()

# %%
print(X.shape)
print(Y.shape)
# Out:
# (784, 999)
# (10, 999)

# %%
def tanh(x):
    return np.tanh(x)

def relu(x):
    return np.maximum(x, 0)

def softmax(x):
    expX = np.exp(x)
    return expX/np.sum(expX, axis = 0)

# %% [markdown]
# /

# %%
n_x=X.shape[0]
n_y=Y.shape[0]
n_h=999

n_h
# Out:
# 999

# %%
w1 = np.random.randn(n_h, n_x)*0.01
b1 = np.zeros((n_h, 1))
    
w2 = np.random.randn(n_y, n_h)*0.01
b2 = np.zeros((n_y, 1))

# %%
print(w1.shape)
print(X.shape)
# Out:
# (999, 784)
# (784, 999)

# %%
def forward_pro(w1,b1,w2,b2,X):
    z1=np.dot(w1,X)+b1
    a1=tanh(z1)
    z2=np.dot(w2,a1)+b2
    a2=softmax(z2)
    
    
    return z1,a1,z2,a2

# %%
def cost(Y,a2):
    m=Y.shape[1]
    cost = -(1/m)*np.sum(Y*np.log(a2))
    return cost

# %%
z1,a1,z2,a2=forward_pro(w1,b1,w2,b2,X)

# %%
a2.shape
# Out:
# (10, 999)

# %%
cost(Y,a2)
# Out:
# 2.3139247357561716

# %%
def back_prog(w1,w2,a1,a2,X,Y):
    m=Y.shape[1]
    
    dz2=a2-Y
    dw2=1/m*(np.dot(dz2,a1.T))
    db2=1/m*(np.sum(dz2,axis=1,keepdims = True))
    dz1=(1/m)*np.dot(w2.T, dz2)*tanh(a1)
    dw1=1/m*(np.dot(dz1,X.T))
    db1=1/m*(np.sum(dz1,axis=1,keepdims = True))
    
    
    return dw1,dw2,db1,db2

# %%
dw1,dw2,db1,db2=back_prog(w1,w2,a1,a2,X,Y)

# %%
dw1.shape
# Out:
# (999, 784)

# %%
w1.shape
# Out:
# (999, 784)

# %%
def update_params(w1,w2,b1,b2,dw1,dw2,db1,db2,lr=0.01):
    w1 -=lr*dw1
    w2 -=lr*dw2
    b1 -=lr*db1
    b2 -=lr*db2
    
    return w1,w2,b1,b2

# %%
def model(X,Y,iteration=1000):
    n_x=X.shape[0]
    n_y=Y.shape[0]
    n_h=999
    w1 = np.random.randn(n_h, n_x)*0.01
    b1 = np.zeros((n_h, 1))
    
    w2 = np.random.randn(n_y, n_h)*0.01
    b2 = np.zeros((n_y, 1))
    start=time.time()
    looptime=0
    for i in range(iteration):
        z1,a1,z2,a2=forward_pro(w1,b1,w2,b2,X)
        
        
        cost_v=cost(Y,a2)
        
        
        
        dw1,dw2,db1,db2=back_prog(w1,w2,a1,a2,X,Y)
        
        
        w1,w2,b1,b2=update_params(w1,w2,b1,b2,dw1,dw2,db1,db2,lr=0.01)
        
        
        if i%100==0:
            print(looptime)
            print("iteration {}  cost {} {:.2f} sec".format(i,cost_v,time.time()-start))
        
        
            
        
        
    return w1,w2,b1,b2

# %%
import time

# %%
w1,w2,b1,b2=model(X,Y)
# Out:
# 0
# iteration 0  cost 2.297430516265475 0.11 sec
# 0
# iteration 100  cost 0.5101718098729671 11.93 sec
# 0
# iteration 200  cost 0.3475358669241577 24.28 sec
# 0
# iteration 300  cost 0.2744017908141412 36.27 sec
# 0
# iteration 400  cost 0.23286318619156246 48.70 sec
# 0
# iteration 500  cost 0.20613441443027464 60.90 sec
# 0
# iteration 600  cost 0.18821137553225992 72.25 sec
# 0
# iteration 700  cost 0.17577707029191514 85.14 sec
# 0
# iteration 800  cost 0.16775925944129988 97.89 sec
# 0
# iteration 900  cost 0.1625654198102281 109.19 sec

# %%
def predict(Xtest,w1,w2,b1,b2):
    z1,a1,z2,a2=forward_pro(w1,b1,w2,b2,Xtest)
    return a2

# %%
def accuracy(ytest,ypred):
    ypredv = np.argmax(ypred, 0) 
    
    ytestv = np.argmax(ytest, 0)
    
    acc = np.mean(ypredv == ytestv)*100
    
    return acc

# %%
xtest=pd.read_csv("test_X.csv").values.T

# %%
ytest=pd.read_csv("test_label.csv").values.T

# %%
ypred=predict(xtest,w1,w2,b1,b2)

# %%
accuracy(ytest,ypred)
# Out:
# 86.81948424068769

# %%
xtest.shape
# Out:
# (784, 349)

# %%
for i in range(349):
    print("Actual")
    plt.imshow(xtest[:,i].reshape(28, 28), cmap = 'gray')
    plt.show()
    print("Predicted {} ".format(np.argmax(ypred[:,i], 0)))
# Out:
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 8
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 8
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 0
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 5
# Actual
# Predicted 1
# Actual
# Predicted 5
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 1
# Actual
# Predicted 2
# Actual
# Predicted 3
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 6
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 3
# Actual
# Predicted 7
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 8
# Actual
# Predicted 2
# Actual
# Predicted 0
# Actual
# Predicted 6
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 2
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 8
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 5
# Actual
# Predicted 2
# Actual
# Predicted 3
# Actual
# Predicted 9
# Actual
# Predicted 8
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 5
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 2
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 6
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 0
# Actual
# Predicted 9
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 0
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 7
# Actual
# Predicted 3
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 4
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 1
# Actual
# Predicted 5
# Actual
# Predicted 8
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 4
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 5
# Actual
# Predicted 8
# Actual
# Predicted 3
# Actual
# Predicted 3
# Actual
# Predicted 5
# Actual
# Predicted 3
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 0
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 0
# Actual
# Predicted 6
# Actual
# Predicted 0
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 6
# Actual
# Predicted 5
# Actual
# Predicted 6
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 2
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 3
# Actual
# Predicted 9
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 2
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 9
# Actual
# Predicted 7
# Actual
# Predicted 7
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 9
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 9
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 8
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 7
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 7
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
# Actual
# Predicted 9
