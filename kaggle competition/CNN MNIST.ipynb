# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dropout
import keras

# %%
data=pd.read_csv("/kaggle/input/digit-recognizer/train.csv")

# %%
data.head()

# %%
import matplotlib.pyplot as plt

# %%
X=data.iloc[:,1:].values
Y=data.iloc[:,0]

# %%
from sklearn.preprocessing import StandardScaler

# %%
Xs=StandardScaler()
XS=Xs.fit_transform(X)

# %%
X.shape

# %%
plt.imshow(XS[1].reshape(28,28),cmap="gray")

# %%
XS.shape

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(XS,Y,test_size=0.1)

# %%
ytrain

# %%
classifier=Sequential()
#1
classifier.add(Conv2D(filters=200,kernel_size=(5,5),activation="relu",padding="same",input_shape=(28,28,1)))
classifier.add(MaxPooling2D((2,2)))

#2nd
classifier.add(Conv2D(filters=225,kernel_size=(3,3),activation="relu",padding="same"))
classifier.add(MaxPooling2D((1,1)))

#3rd
classifier.add(Conv2D(filters=250,kernel_size=(3,3),activation="relu"))
classifier.add(MaxPooling2D((2,2)))

classifier.add(Conv2D(filters=256,kernel_size=(5,5),activation="relu"))
classifier.add(MaxPooling2D((2,2)))




classifier.add(keras.layers.Flatten())


classifier.add(Dense(units=1000,activation="relu",kernel_initializer='he_uniform'))



classifier.add(Dense(units=10,activation="softmax"))

# %%
classifier.summary()

# %%
# classifier.add(Dense(units=3000,activation="relu",kernel_initializer='he_uniform',input_dim=784))
# classifier.add(Dropout(0.4))

# %%
# classifier.add(Dense(units=2500,activation="relu",kernel_initializer='he_uniform'))

# classifier.add(Dense(units=1000,activation="relu",kernel_initializer='he_uniform'))


# classifier.add(Dense(units=750,activation="relu",kernel_initializer='he_uniform'))
# classifier.add(Dropout(0.3))

# classifier.add(Dense(units=500,activation="relu",kernel_initializer='he_uniform'))
# classifier.add(Dropout(0.3))

# %%
# classifier.add(Dense(units=50,activation="relu",kernel_initializer='he_uniform'))

# %%
# classifier.add(Dense(units=10,activation="softmax"))

# %%
classifier.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
xtrain.shape

# %%
xt=xtrain.reshape(37800,28,28,1)

# %%
xt.shape

# %%
xtrain.shape

# %%
model=classifier.fit(xt,ytrain,validation_split=0.1,batch_size=1024,epochs=10)

# %%
yp=classifier.predict(xtest.reshape(4200,28,28,1))

# %%
true=0
false=0
for i in range(4200):
    if ytest.iloc[i]==np.argmax(yp[i,:]):
        true +=1
    else:
        false +=1

# %%
true

# %%
true

# %%
true

# %%
false

# %%
true/(true+false)

# %%
true

# %%
false

# %%
test=pd.read_csv("/kaggle/input/digit-recognizer/test.csv")

# %%
X_test=test.values

# %%
X_test.shape

# %%
yp=classifier.predict(Xs.transform(X_test).reshape(28000,28,28,1))

# %%
len(yp)

# %%
np.argmax(yp[2399])

# %%
len(yp)

# %%
plt.imshow(X_test[2399].reshape(28,28))

# %%
ypred=[]
for i in yp:
    ypred.append((np.argmax(i)))

# %%
ypred[:20]

# %%
for k in range(20):
    plt.imshow(X_test[k].reshape(28,28))
    plt.show()

# %%
output=pd.DataFrame(np.arange(1,len(X_test)+1),columns=["ImageId"])

# %%
output["Label"]=ypred

# %%
output

# %%
output.to_csv("final1601.csv",index=False)

# %%
test.value_counts()
